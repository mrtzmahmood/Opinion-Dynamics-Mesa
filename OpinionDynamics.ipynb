# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from opinion_dynamics.agent import odAgent
from opinion_dynamics.model import odModel

# %%
opinion={}
mean_opinion=[]
median_opinion=[]
model = odModel(N = 200,
                min_eps = 0, 
                max_eps = 0.5, 
                alpha = 2, 
                beta = 4, 
                cr = 'HK', 
                agg = 'mean', 
                ee_rate = 0.02, 
                ext_range = 0, 
                ext_type = 'two side', 
                org = False, 
                width = 100, 
                height =100,
                max_iters = 500)
opinion = model.run_model ()

# %%
model_out = model.dc.get_model_vars_dataframe()
opinion_dynamics = model_out[['Opinion mean', 'Opinion median']]

# %%
ax = opinion_dynamics.plot()
ax.set_title('Opinion Dynamics Over Time')
ax.set_xlabel('Step')
ax.set_ylabel('opinion')
_ = ax.legend(bbox_to_anchor=(1.35, 1.025))

# %%
agent_out = model.dc.get_agent_vars_dataframe()
opinion = agent_out['opinion'][199]
eps = agent_out['eps'][199]

# %%
ax = opinion.hist()
ax.set_title('Opinion Histogram')
ax.set_xlabel('opinion')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
ax = eps.hist()
ax.set_title('eps Histogram')
ax.set_xlabel('eps')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')
